# %%
from textblob import TextBlob
import wikipedia

# %%
golden_state_warriors_text = wikipedia.summary("Golden State Warriors")
golden_state_warriors_text
# Out:
# 'The Golden State Warriors are an American professional basketball team based in San Francisco. The Warriors compete in the National Basketball Association (NBA) as a member of the Pacific Division of the Western Conference. Founded in 1946 in Philadelphia, the Warriors moved to the San Francisco Bay Area in 1962 and took the city\'s name before changing its geographic moniker to Golden State in 1971. The team plays its home games at Chase Center.\nThe Warriors won the inaugural Basketball Association of America (BAA) championship in 1947, and won again in 1956, led by Hall of Fame trio Paul Arizin, Tom Gola, and Neil Johnston. After the trade of star Wilt Chamberlain in January 1965, the team finished the 1964–65 season with the NBA\'s worst record (17–63). Their rebuilding period was brief, however, as they drafted Rick Barry four months after the trade. Barry, along with Jamaal Wilkes, powered the Warriors to their third championship in 1975, widely considered one of the biggest u
# ...

# %%
blob = TextBlob(golden_state_warriors_text)
blob
# Out:
# TextBlob("The Golden State Warriors are an American professional basketball team based in San Francisco. The Warriors compete in the National Basketball Association (NBA) as a member of the Pacific Division of the Western Conference. Founded in 1946 in Philadelphia, the Warriors moved to the San Francisco Bay Area in 1962 and took the city's name before changing its geographic moniker to Golden State in 1971. The team plays its home games at Chase Center.
# ...

# %%
blob.tags
# Out:
# [('The', 'DT'),
#  ('Golden', 'NNP'),
#  ('State', 'NNP'),
#  ('Warriors', 'NNS'),
#  ('are', 'VBP'),
#  ('an', 'DT'),
#  ('American', 'JJ'),
#  ('professional', 'NN'),
#  ('basketball', 'NN'),
#  ('team', 'NN'),
#  ('based', 'VBN'),
#  ('in', 'IN'),
#  ('San', 'NNP'),
#  ('Francisco', 'NNP'),
#  ('The', 'DT'),
#  ('Warriors', 'NNP'),
#  ('compete', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('National', 'NNP'),
#  ('Basketball', 'NNP'),
#  ('Association', 'NNP'),
#  ('NBA', 'NNP'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('member', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Pacific', 'NNP'),
#  ('Division', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Western', 'JJ'),
#  ('Conference', 'NNP'),
#  ('Founded', 'VBN'),
#  ('in', 'IN'),
#  ('1946', 'CD'),
#  ('in', 'IN'),
#  ('Philadelphia', 'NNP'),
#  ('the', 'DT'),
#  ('Warriors', 'NNS'),
#  ('moved', 'VBD'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('San', 'NNP'),
#  ('Francisco', 'NNP'),
#  ('Bay', 'NNP'),
#  ('Area', 'NNP'),
# ...

# %%
blob.noun_phrases
# Out:
# WordList(['golden state', 'warriors', 'american professional basketball team', 'san francisco', 'warriors', 'national basketball association', 'nba', 'pacific division', 'western conference', 'founded', 'philadelphia', 'warriors', 'san francisco', 'bay area', "city 's name", 'geographic moniker', 'golden state', 'team plays', 'home games', 'chase', 'warriors', 'inaugural basketball association', 'america', 'baa', 'fame', 'paul arizin', 'tom gola', 'neil johnston', 'wilt chamberlain', 'january', 'nba', 'rick barry', 'barry', 'jamaal wilkes', 'warriors', 'nba', 'playoff regulars', 'tim hardaway', 'mitch richmond', 'chris mullin', 'run tmc', 'stephen curry', 'klay thompson', 'draymond', 'championship glory', 'warriors', 'best-ever regular-season record', 'finals', 'cleveland cavaliers', 'series lead', 'kevin durant', 'back-to-back championships', 'finals', 'toronto raptors', 'durant', 'warriors', 'boston celtics', 'finals', 'nicknamed', 'dubs', "w 's", 'warriors', 'nba', 'regular season
# ...

# %%
from nlplogic import corenlp

name = "Golden State Warriors"

phrases = corenlp.get_phrases(name)
phrases
# Out:
# Finding wikipedia summary for name: Golden State Warriors
# ...
